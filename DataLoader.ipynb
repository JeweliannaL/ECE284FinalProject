# %%
# !pip install tifffile torch torchvision pandas numpy
# Out:
# Requirement already satisfied: tifffile in /opt/conda/lib/python3.12/site-packages (2025.12.12)
# Requirement already satisfied: torch in /opt/conda/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.12/site-packages (0.21.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy!=1.13.2,>=1.13.1 in /opt/conda/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.5,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy!=1.13.2,>=1.13.1->torch) (1.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)

# %%
from skin_biopsy_dataset import build_dataloaders

train_loader, test_loader, classes = build_dataloaders(
    csv_path = "SkinBiopsyAnnotation.csv",
    root_dir = "/path/to/tiff/files",
    image_size  = 224,
    batch_size  = 8,
    num_workers = 4,
)
# Out:
# =======================================================
#   Select the Classification Option (label_col):
# =======================================================
#   [1]  category  — 3  types: BCC / SCC / negative
#   [2]  type      — 8  types: BCC / SCC / SK / nevus / AK / negative ...
#   [3]  subtype   — 13 types: BCC-nodular / SCC-welldiff / BCC-infiltrative ...
# =======================================================
#   Enter Code (1 / 2 / 3):  2
#   ✓ Selected: type      — 8  types: BCC / SCC / SK / nevus / AK / negative ...
#
#
# [SkinBiopsyDataset | split='train' | label_col='type']
#   Total sample: 254
#   Caregory Distribution:
#     [0] AK                           5 █
#     [1] BCC                        123 █████████████████████████████████████████
#     [2] SCC                         73 ████████████████████████
#     [3] SK                          15 █████
#     [4] negative                    31 ██████████
#     [5] nevus                        7 ██
#
# [SkinBiopsyDataset | split='test' | label_col='type']
#   Total sample: 73
#   Caregory Distribution:
#     [0] AK                           2
#     [1] BCC                         33 ███████████
#     [2] SCC                         19 ██████
#     [3] SK                           6 ██
#     [4] negative                    12 ████
#     [5] nevus                        1
#
# ✓ DataLoader Constructed successfully
#   label_col  : type
#   classes    : ['AK', 'BCC', 'SCC', 'SK', 'negative', 'nevus']
#   image_size : 224×224
#   batch_size : 8
#   train      : 254 samples → 32 batches
#   test       : 73  samples → 10 batches
